# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # exception
#
# > customized exceptions

# %%
#| default_exp system.exception

# %%
#| export
class ReadOnlyError(Exception):
    pass

# %%
#| export
class WriteOnlyError(Exception):
    pass

# %%
#| export
class RobotIDError(Exception):
    pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()
